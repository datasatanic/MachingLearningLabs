# %% [markdown]
# # Задание 1

# %%
# %run Lab5.py
# %matplotlib inline

# %% [markdown]
# # Задание 2

# %%
# %run Lab5_1.py
# Out:
# Additive:51.70% Multiplicative:16.90% WithoutNoize:73.60%
#  {(-1, -1, -1, 1): 248, (-1, -1, 1, -1): 246, (-1, -1, 1, 1): 242}

# %% [markdown]
# # Задание 3

# %%
# %run Lab5_2.py
